# %%
class FizzBuzzGame:
    def __init__(self, limit):
        self.limit = limit

    def play(self):
        for i in range(1, self.limit + 1):
            output = ""
            if i % 3 == 0:
                output += "Fizz"
            if i % 5 == 0:
                output += "Buzz"
            if not output:  
                print(i)
            else:
                print(output)


if __name__ == "__main__":
    print("Fizz Buzz up to 15:")
    game1 = FizzBuzzGame(15)
    game1.play()
    print("-" * 20)

    print("Fizz Buzz up to 30:")
    game2 = FizzBuzzGame(30)
    game2.play()
# Out:
# Fizz Buzz up to 15:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# --------------------
# Fizz Buzz up to 30:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz

# %%
class MovieBudgetAnalyzer:
    
    def __init__(self):
        
        self.movies = [
            ("Eternal Sunshine of the Spotless Mind", 20000000),
            ("Memento", 9000000),
            ("Requiem for a Dream", 4500000),
            ("Pirates of the Caribbean: On Stranger Tides", 379000000),
            ("Avengers: Age of Ultron", 365000000),
            ("Avengers: Endgame", 356000000),
            ("Incredibles 2", 200000000)
        ]
        
    def add_movies_from_user(self):
        
        add_new = input("Do you want to add more movies to the dataset? (yes/no): ").lower()
        if add_new != 'yes':
            print("Continuing with the original dataset.")
            return

        try:
            num_to_add = int(input("How many movies would you like to add?: "))
            for i in range(num_to_add):
                movie_name = input(f"Enter the name of movie {i + 1}: ")
                while True:
                    try:
                        movie_budget = int(input(f"Enter the budget for '{movie_name}': "))
                        self.movies.append((movie_name, movie_budget))
                        break
                    except ValueError:
                        print("Invalid input. Please enter a number for the budget.")
        except ValueError:
            print("Invalid input. Please enter a number for how many movies you want to add.")
            
    def analyze_budgets(self):
       
        if not self.movies:
            print("The movie list is empty. Cannot perform calculations.")
            return

        
        total_budget = sum(budget for name, budget in self.movies)

        
        average_budget = total_budget / len(self.movies)
        print(f"The average budget of the films is: ${average_budget:,.2f}")

      
        high_budget_count = 0
        print("Movies with a budget higher than the average:")
        for name, budget in self.movies:
            if budget > average_budget:
                high_budget_count += 1
                difference = budget - average_budget
                print(f"- '{name}' with a budget of ${budget:,}, which is ${difference:,.2f} higher than the average.")
        
        
        print(f"Total films with a budget higher than the average: {high_budget_count}")


if __name__ == "__main__":
    
    analyzer = MovieBudgetAnalyzer()
    
    analyzer.add_movies_from_user()
    
    
    analyzer.analyze_budgets()
# Out:
# Continuing with the original dataset.
# The average budget of the films is: $190,500,000.00
# Movies with a budget higher than the average:
# - 'Pirates of the Caribbean: On Stranger Tides' with a budget of $379,000,000, which is $188,500,000.00 higher than the average.
# - 'Avengers: Age of Ultron' with a budget of $365,000,000, which is $174,500,000.00 higher than the average.
# - 'Avengers: Endgame' with a budget of $356,000,000, which is $165,500,000.00 higher than the average.
# - 'Incredibles 2' with a budget of $200,000,000, which is $9,500,000.00 higher than the average.
# Total films with a budget higher than the average: 4
